# %%
# !pip install llama-index llama-index-llms-groq llama-index-embeddings-huggingface
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 24.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 37.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 57.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 176.8/176.8 kB 12.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 861.9/861.9 kB 42.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 295.8/295.8 kB 19.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 48.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.5/49.5 kB 3.3 MB/s eta 0:00:00
# ...
#   Attempting uninstall: tenacity
#     Found existing installation: tenacity 9.0.0
#     Uninstalling tenacity-9.0.0:
#       Successfully uninstalled tenacity-9.0.0
#   Attempting uninstall: nltk
#     Found existing installation: nltk 3.8.1
#     Uninstalling nltk-3.8.1:
#       Successfully uninstalled nltk-3.8.1
# ...

# %%
import os

# %%
GROQ_API_KEY = "key here"

# %%
os.environ["GROQ_API_KEY"] = GROQ_API_KEY

# %%
import nest_asyncio

nest_asyncio.apply()

# %%
from llama_index.core import SimpleDirectoryReader
from llama_index.core import SummaryIndex
from llama_index.llms.groq import Groq
from llama_index.core.node_parser import SentenceSplitter
from llama_index.core import Settings
from llama_index.embeddings.huggingface import HuggingFaceEmbedding

# %%
llm = Groq(model="llama-3.1-8b-instant")

Settings.llm = llm
Settings.embed_model = HuggingFaceEmbedding()
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/90.8k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/52.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/684 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/133M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/366 [00:00<?, ?B/s]
# ...

# %%
# load the document
documents = SimpleDirectoryReader(input_files=["/content/51 (3).pdf"]).load_data()

# %%
print(type(documents))
# Out:
# <class 'list'>

# %%
len(documents)
# Out:
# 10

# %%
documents[0]
# Out:
# Document(id_='fa068a97-76ab-4839-bc88-165b31de3bec', embedding=None, metadata={'page_label': '1', 'file_name': '51 (3).pdf', 'file_path': '/content/51 (3).pdf', 'file_type': 'application/pdf', 'file_size': 1584736, 'creation_date': '2024-11-07', 'last_modified_date': '2024-11-07'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, text='Cross Examine: An Ensemble-based approach to leverage Large Language\nModels for Legal Text Analytics\nAnonymous ACL submission\nAbstract 001\nLegal documents are complex in nature, de- 002\nscribing a course of argumentative reasoning 003\nthat is followed to settle a case. Churning 004\nthrough large volumes of legal documents is a 005\ndaily requirement for a large number of profes- 006\nsionals who need access to the inform
# ...

# %%
documents[1]
# Out:
# Document(id_='1e4bde21-cb16-4f5d-b86d-759def9755c0', embedding=None, metadata={'page_label': '2', 'file_name': '51 (3).pdf', 'file_path': '/content/51 (3).pdf', 'file_type': 'application/pdf', 'file_size': 1584736, 'creation_date': '2024-11-07', 'last_modified_date': '2024-11-07'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, text='fact that LLMs are known to hallucinate, or gen- 083\nerate text that may not be contextually relevant or 084\ncorrect, which is also not quite acceptable for le- 085\ngal text processing tasks. The current work was 086\nmotivated by these challenges and sought to ex- 087\nplore whether these challenges can be overcome 088\nor bypassed, thereby easing the tasks of legal doc- 089\nument summarization and question answering for 0
# ...

# %%
splitter = SentenceSplitter(chunk_size=2048)
nodes = splitter.get_nodes_from_documents(documents)

# %%
summary_index = SummaryIndex(nodes)

# %%
summary_query_engine = summary_index.as_query_engine(
    response_mode="tree_summarize",
    use_async=True
)

# %%
response = summary_query_engine.query("Explain me the research paper in details and what are its drawback")

# %%
print(type(response))
# Out:
# <class 'llama_index.core.base.response.schema.Response'>

# %%
print(response)
# Out:
# The research paper presents an ensemble-based approach to leverage Large Language Models (LLMs) for legal text analytics. The primary goal of this research is to develop a novel workflow that can efficiently process large volumes of legal documents, extract key information, and provide analytical insights.
#
# The paper proposes a two-phase approach for legal text analytics. In the first phase, the researchers use a "summary of summaries" approach, which involves generating contextually relevant summaries from long court proceedings using Retrieval-Augmented Generation (RAG) and LLMs. The summaries are then used to extract legal information, which is stored in a knowledge graph designed following a legal ontology.
#
# ...

# %%
import pandas as pd

# Sample data (replace this with your actual data)
answers = {"""
   q1.1: Female
q1.2: The victim is a female.
q1.3: The victim identifies as a female.

q2.1: Minor
q2.2: The victim is legally considered a minor under the age of majority.
q2.3: The victim is under the legal age of adulthood.

q3.1: Male
q3.2: The accused is a male.
q3.3: The accused identifies as a male.

q4.1: Not minor
q4.2: The accused is not legally considered a minor under the age of majority.
q4.3: The accused is not under the legal age of adulthood.

q5.1: State of Meghalaya
q5.2: The State of Meghalaya filed the bail application.
q5.3: The State of Meghalaya initiated the process of filing the bail application.

q6.1: No relation
q6.2: The State of Meghalaya has no direct relationship with the accused.
q6.3: The State of Meghalaya is the prosecuting authority.

q7.1: Yes
q7.2: The accused was known to the victim.
q7.3: There was a pre-existing familiarity between the victim and the accused.

q8.1: IPC and POCSO Act
q8.2: The accused was booked under the Indian Penal Code and the Protection of Children from Sexual Offenses Act.
q8.3: The accused was implicated under sections 342, 354, 376(2)(a)(i), and 506 IPC, and sections 6 and 10 of the POCSO Act.

q9.1: No
q9.2: The accused has not engaged in a repeated offense.
q9.3: The accused did not commit the same offense again.

q10.1: Yes
q10.2: The accused received bail approval.
q10.3: Bail approval was given to the accused.

q11.1: Bail granted
q11.2: The judge granted bail to the accused.
q11.3: The judge finally granted bail to the accused.

q12.1: Seriousness of offenses and potential threat to investigation
q12.2: The judge provided the rationale for the verdict based on the seriousness of the offenses and the potential threat to the investigation.
q12.3: The judge justified the ruling by considering the seriousness of the offenses and the potential threat to the investigation.

q13.1: Indian Penal Code and Protection of Children from Sexual Offenses Act
q13.2: The Indian Penal Code and the Protection of Children from Sexual Offenses Act influenced the document.
q13.3: The IPC and POCSO Act are mentioned as reference points in the document.

q14.1: Indian jurisdiction
q14.2: The case falls under the Indian jurisdiction.
q14.3: The case lies under the Indian jurisdiction.

q15.1: Not specified
q15.2: The police station where the case was reported is not specified.
q15.3: The case was reported to the police, but the police station is not specified.

q16.1: Against a minor
q16.2: The crime was committed under circumstances where the accused took advantage of the victim's vulnerability as a minor.
q16.3: The offense was perpetrated in a situation where the accused exploited the victim's age and vulnerability."""
}

## Convert answers dictionary into a list of rows, with each row as [question, answer]
data = [[key, value] for key, value in answers.items()]

# Create a DataFrame with each answer in a new row
df = pd.DataFrame(data, columns=['Question', 'Answer'])

# Save to Excel file
df.to_excel('/mnt/data/answers_output.xlsx', index=False)

print("Data has been saved to 'answers_output.xlsx'")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-44-37a47bce6de5> in <cell line: 71>()
#      69
#      70 ## Convert answers dictionary into a list of rows, with each row as [question, answer]
# ---> 71 data = [[key, value] for key, value in answers.items()]
#      72
#      73 # Create a DataFrame with each answer in a new row
#
# AttributeError: 'set' object has no attribute 'items'

# %%
print(type(response_sum))
# Out:
# <class 'str'>

# %%
# load the document
documents = SimpleDirectoryReader(input_files=["/content/rLMfPKB9xy.pdf"]).load_data()

# %%
splitter = SentenceSplitter(chunk_size=256)
nodes = splitter.get_nodes_from_documents(documents)

# %%
question_index = SummaryIndex(nodes)

# %%
question_query_engine = question_index.as_query_engine(
    response_mode="tree_summarize",
    use_async=True
)

# %%
questions_df.iloc[26:]
# Out:
#    Unnamed: 0      q                                   Questions_Levels  \
# 26        NaN   q9.3     Did the accused commit the same offense again?
# 27        Q10  q10.1                  Was bail granted to the accused ?
# 28        NaN  q10.2             Did the accused receive bail approval?
# 29        NaN  q10.3            Was bail approval given to the accused?
# 30        Q11  q11.1  Under the jurisdiction of which court is the c...
# 31        NaN  q11.2      In which court is the case being adjudicated?
# 32        NaN  q11.3       At which court is the case undergoing trial?
# 33        Q12  q12.1    What were the judge's reasons for the decision?
# 34        NaN  q12.2  What rationale did the judge provide for the v...
# 35        NaN  q12.3  What were the judge's justifications for the r...
# 36        Q13  q13.1  Which legal principle, landmark judgment, or p...
# 37        NaN  q13.2  "What guiding legal principle, significant cas...
# ...

# %%
import pandas as pd
import openpyxl

# Assuming you already have a summarized text in `response_sum`
response_sum = "Your summarized text here."

# Step 1: Read the Excel file containing questions using openpyxl or pd.read_excel
try:
    # Try reading with openpyxl (more robust for Excel files)
    questions_df = pd.read_excel('/content/questions (1).xlsx')
except Exception as e:
    print(f"Error reading with openpyxl: {e}")
    try:
        # Fallback to pd.read_excel with explicit engine
        questions_df = pd.read_excel('/content/questions (1).xlsx', engine='openpyxl')
    except Exception as e:
        print(f"Error reading with pd.read_excel: {e}")
        # If both fail, you may need to investigate file format or encoding further

# Step 2: Create a list to store the results
results = []
count =0
# Step 3: Loop over each question in the CSV
#for index, row in questions_df.iterrows():
for index, row in questions_df.iloc[26:].iterrows():
    question = row['Questions_Levels']  # Get the current question

    # Modify the query to include the summary text as context
    # Instead of passing source_documents, prepend the summary to the question
   # query_with_context = f"{response_sum} \n\nQuestion: {question}"
    count= count +1
    print(count)
    # Query the summarization engine
    response = response = question_query_engine.query(question)

    # Step 4: Append the question and response to results
    results.append({
        'Question': question,
        'Response': response.response  # Assuming 'response.response' contains the text answer
    })

# Step 5: Save the results to an Excel file
results_df = pd.DataFrame(results)
results_df.to_excel('answers.xlsx', index=False)
# Out:
# 1
# WARNING:llama_index.llms.openai.utils:Retrying llama_index.llms.openai.base.OpenAI._chat in 0.343914251434301 seconds as it raised RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama-3.1-8b-instant` in organization `org_01javs9ysefnpazvw3sdpkqqtv` on : Limit 500000, Used 500348, Requested 278. Please try again in 1m48.2226s. Visit https://console.groq.com/docs/rate-limits for more information.', 'type': '', 'code': 'rate_limit_exceeded'}}.
# WARNING:llama_index.llms.openai.utils:Retrying llama_index.llms.openai.base.OpenAI._chat in 1.5982686283696075 seconds as it raised RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama-3.1-8b-instant` in organization `org_01javs9ysefnpazvw3sdpkqqtv` on : Limit 500000, Used 500345, Requested 278. Please try again in 1m47.7726s. Visit https://console.groq.com/docs/rate-limits for more information.', 'type': '', 'code': 'rate_limit_exceeded'}}.
# ...

# %%
# storing the document summary index
#summary_index.storage_context.persist("doc_summary_index")

# %%
results_df = pd.DataFrame(results)
results_df.to_excel('answers.xlsx', index=False)
