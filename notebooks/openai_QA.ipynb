# %%
from openai import OpenAI
import os
import tiktoken
from tqdm import tqdm
import PyPDF2
import re
import pandas as pd
from typing import List, Tuple, Optional
from pydantic import BaseModel
from textwrap import dedent

# %%
OpenAI.api_key = os.getenv('OPENAI_API_KEY')
client = OpenAI()
MODEL = 'gpt-4o-mini'
DIR = 'C:/Users/suyog/Desktop/monsoon_24/capstone-legal-docs-analysis/Docs/fs_cases/'

# %%
def read_pdf(file_path):
    with open(file_path, 'rb') as file:
        reader = PyPDF2.PdfReader(file)
        text = ''
        for page in range(len(reader.pages)):
            text += reader.pages[page].extract_text()
                    
        text = re.sub(r'Indian Kanoon - http://indiankanoon.org/doc/\d+/ \d', '', text)
        text = re.sub(r'http://www.judis.nic.in', '', text)
    
        return text

# %%
df = pd.read_csv('food_safety_newdocs.csv')
docs = df['file_name'].to_list()
docs
# token_lengths = pd.DataFrame(columns=['doc', 'token_length'])
# for doc in tqdm(docs):
#     text = read_pdf(DIR + doc)
#     encoding = tiktoken.encoding_for_model('gpt-4o-mini')
#     token_lengths.loc[len(token_lengths)] = [doc, len(encoding.encode(text))]
# Out:
# ['8_vs_Wood_Craft_Products_1995_on_21_February_2015.PDF',
#  'Adab_vs_State_Of_U_P_And_4_Others_on_9_May_2023.PDF',
#  'Aditya_Birla_Retail_Ltd_Ludhiana_vs_Food_Safety_Officer_Ludhiana_on_14_March_2018.PDF',
#  'Agro_Tech_Foods_Limited_vs_The_State_Of_Rajasthan_on_27_May_2019.PDF',
#  'Akuthota_Narasimha_vs_The_State_Of_Telangana_on_22_June_2021.PDF',
#  'Alpeshbhai_Babubhai_Pathodiya_vs_State_Of_Gujarat_3_on_24_November_2017.PDF',
#  'Alpeshbhai_Babubhai_Pathodiya_vs_State_Of_Gujarat_on_4_December_2018.PDF',
#  'Amar_Kumar_Khabare_Amar_Khabare_vs_The_State_Of_Jharkhand_on_1_May_2019.PDF',
#  'Amir_Ahamad_vs_Commissioner_Of_Food_Safety_And_on_22_July_2022.PDF',
#  'Amit_vs_The_State_Of_Madhya_Pradesh_on_21_April_2018.PDF',
#  'Anant_Sharma_Anr_vs_The_Abjudicating_Officer_Ors_on_12_March_2018.PDF',
#  'Anil_Kumar_Mishra_vs_Addl_Distt_Session_Judge_Vii_on_19_December_2019.PDF',
#  'Anil_Yadav_Proprietor_Of_Ms_Anil_Sweets_vs_State_Of_Jharkhand_And_Ors_on_25_April_2016.PDF',
#  'Anup_Kumar_vs_Food_Safety_Appellate_Tribunal_And_2_on_2_May_2023.PDF',
#  'AO_171_2023_on_7_October_2023.PDF',
#  'AO_171_2023_on_9_August_2023.PDF',
#  'AO_305_2024_on_12_August_2024.PDF',
#  'AO_305_2024_on_21_August_2024.PDF',
#  'Ardor_Restaurant_And_Ors_vs_Bal_Mukund_Food_Safety_Officer_on_13_March_2019.PDF',
#  'Arjun_Prasad_Sah_Arjun_Sah_vs_The_State_Of_Bihar_Through_The_on_15_May_2017.PDF',
#  'Arjun_Prasad_Sah_Arjun_Sah_vs_The_State_Of_Bihar_Through_The_on_16_February_2017.PDF',
raman_Yadav_vs_The_State_Of_Madhya_Pradesh_on_17_September_2024.PDF',
#  'Raman_Yadav_vs_The_State_Of_Madhya_Pradesh_on_3_September_2024.PDF',
#  'Rameshkumar_Narendar_Tiwari_vs_The_State_Of_Maharashtra_And_Another_on_4_March_2016.PDF',
#  'Ramprakash_Bhutra_vs_State_Of_Rajasthan_on_2_August_2019.PDF',
#  'Ram_Anuj_Maurya_And_Another_vs_State_Of_U_P_And_2_Others_on_21_August_2023.PDF',
#  'Ram_Babu_vs_State_Of_U_P_And_3_Others_on_12_March_2021.PDF',
#  'Ram_Chandra_Agarwal_vs_The_State_Of_Jharkhand_And_Others_on_28_July_2022.PDF',
#  'Ram_Paul_vs_State_Of_Punjab_And_Others_on_12_December_2022.PDF',
#  'Ratnadip_Nanasaheb_Bhise_And_Ors_vs_Maharashtra_Public_Service_Commission_on_2_May_2023.PDF',
#  'Ravindrakumar_Singh_vs_Food_Safety_Appellate_Tribunal_5_on_4_December_2017.PDF',
#  'Ravi_Jain_vs_The_State_Of_Jharkhand_Ors_on_19_July_2022.PDF',
#  'Ravi_Kumar_S_O_Shri_Baldev_Prasad_vs_State_Of_Rajasthan_on_24_February_2022.PDF',
#  'Riyazuddin_vs_State_Of_U_P_And_3_Others_on_2_August_2021.PDF',
#  'R_Chandramohan_vs_The_Food_Safety_Officer_on_1_October_2019.PDF',
#  'Sachin_S_O_Jawaharlal_Jain_vs_The_State_Of_Maharashtra_on_4_March_2016.PDF',
#  'Saddam_vs_State_Of_U_P_And_2_Others_on_17_February_2021.PDF',
#  'Sageer_Ahmad_vs_State_Of_U_P_And_3_Others_on_15_March_2021.PDF',
#  'Salimbhai_Jafarbhai_Jindani_vs_State_Of_Gujarat_2_on_18_September_2015.PDF',
#  'Sambhagiye_Nagrik_Upbhokta_vs_Union_Of_India_on_1_October_2014.PDF',
#  'Samsher_Gani_vs_State_Of_Uttarakhand_Others_on_24_March_2015.PDF',
#  'Samy_Umayal_Traders_vs_State_Of_Kerala_on_19_November_2021.PDF',
#  'Sanjay_Jain_vs_State_Of_Chhattisgarh_on_5_July_2021.PDF',
#  'Sanjay_Kumar_Jaiswal_S_O_Shree_Giraj_vs_State_Of_Rajasthan_on_15_December_2021.PDF']

# %%
def read_single_pdf(path):
    reader = PyPDF2.PdfReader(path)
    text = ''
    for page in range(len(reader.pages)):
        text += reader.pages[page].extract_text()
    
    text = re.sub(r'Indian Kanoon - http://indiankanoon.org/doc/\d+/ \d', '', text)
    text = re.sub(r'http://www.judis.nic.in', '', text)
    
    return text

# %%
questions_prompt = '''
    You will be provided with a court judgment related to a food safety issue. Your task is to answer questions based strictly and concisely based on the provided text. 
    Each response must be in plaintext, avoiding any extra content, commentary, or interpretations beyond what is explicitly stated in the judgment. Use only the information provided. 
    If the text does not contain the required information, respond with "Not specified."
    Here is a description of the parameters:
    - answer: the answer to the question asked.
    '''

class QuestionAnswer(BaseModel):
    answer: str

def question_answering(text: str):
    completion = client.beta.chat.completions.parse(
        model=MODEL,
        temperature=0.0,
        messages=[
            {"role": "system", "content": dedent(questions_prompt)},
            {"role": "user", "content": text}
        ],
        response_format=QuestionAnswer,
    )

    return completion.choices[0].message.parsed

# %%
questions = pd.read_csv(r'C:\Users\suyog\Desktop\monsoon_24\capstone-legal-docs-analysis\sheets\food_safety_questions.csv')
questions = questions[:12]
questions
# Out:
#     question_id                                           question
# 0           1.1       What food product was involved in this case?
# 1           1.2  What type of food product is discussed in this...
# 2           1.3           Which food item is central to this case?
# 3           2.1  Is the petitioner individual, government entit...
# 4           2.2  What classification best describes the petitio...
# 5           2.3  What kind of entity is the petitioner-organiza...
# 6           3.1  Is the respondent individual, government entit...
# 7           3.2  What classification best describes the respond...
# 8           3.3  What kind of entity is the respondent-organiza...
# 9           4.1      What crime was associated with the food item?
# 10          4.2  What unlawful act was committed involving the ...
# 11          4.3  What crime was committed in relation to the fo...

# %%
out_df = pd.DataFrame(columns=['doc', 'question_id', 'question', 'answer'])

# %%
errs = {}
for doc in tqdm(docs):
    try:
        text = read_single_pdf(DIR + doc)
        for i in range(len(questions)):
            text_with_question = text + '\nQuestion:\n' + questions['question'][i]
            answer = question_answering(text_with_question)
            out_df.loc[len(out_df)] = [doc, questions['question_id'][i], questions['question'][i], answer.answer]
            out_df.to_csv(r'C:\Users\suyog\Desktop\monsoon_24\capstone-legal-docs-analysis\sheets\food_safety_answers.csv', index=False)
    except Exception as e:
        print(doc, e)
        errs[doc] = e
        continue
# Out:
# 100%|██████████| 249/249 [58:03<00:00, 13.99s/it]

# %%
for doc in errs.keys():
    #remove the doc from out_df
    if doc in out_df['doc'].values:
        print(f'Removing {doc} from out_df')
        out_df = out_df[out_df['doc'] != doc]
# Out:
# Removing Potta_Suresh_vs_The_State_Of_Andhra_Pradesh_on_22_March_2022.PDF from out_df

# %%
for doc in errs.keys():
    try:
        text = read_single_pdf(DIR + doc)
        if 'Lg_Electronics' in doc:
            print(doc)
            # sample 125k tokens from the text
            text = text[:125000]
        for i in range(len(questions)):
            text_with_question = text + '\nQuestion:\n' + questions['question'][i]
            answer = question_answering(text_with_question)
            print(answer.answer)
            out_df.loc[len(out_df)] = [doc, questions['question_id'][i], questions['question'][i], answer.answer]
            out_df.to_csv(r'C:\Users\suyog\Desktop\monsoon_24\capstone-legal-docs-analysis\sheets\food_safety_answers.csv', index=False)
    except Exception as e:
        print(doc, e)
        errs[doc] = e
        continue
# Out:
# M_S_Lg_Electronics_India_Pvt_Ltd_vs_The_State_Of_Tamil_Nadu_on_31_March_2022.PDF
# NA
# NA
# NA
# 3. organization
# organization
# organization
# government entity
# government entity
# government entity
# NA
# NA
# NA
# NA
# NA
# NA
# tobacco products
# tobacco products
# tobacco products
# 1. individual
# individual
# 2. individual
# 2. government entity
# 3. government entity
# 3. government entity
# NA
# NA
# NA
# 1. the petitioner
# the petitioner
# 1. the petitioner
# NA
# NA
# NA
# NA
# organization
# NA
# organization
# organization
# NA
# NA
# NA
# NA
# 1. the petitioner
# 1. the petitioner
# 1. the petitioner
# NA
# NA
# NA
# individual
# individual
# individual
# 2. government entity
# 3. government entity
# 3. government entity
# NA
# NA
# NA
# 2. the respondent
# 2. the respondent
# 2. the respondent
# Goa Gutkha
# Goa Gutkha products
# Goa Gutkha
# individual
# individual
# individual
# 2. government entity
# 3. government entity
# 3. government entity
# Goa Gutkha products which are banned
# The unlawful act involved the recovery of banned Goa Gutkha products.
# The crime involved the possession of banned Goa Gutkha products.
# 1. the petitioner
# 1. the petitioner
# 1. the petitioner
# NA
# NA
# NA
# 1. individual
# 1. individual
# individual
# 1. individual
# individual
# individual
# Running a restaurant without obtaining the Municipal Health Trade License.
# Defendant no.1 was running his food business in the name of SANKALP RESTAURANT without obtaining the MUNICIPAL HEALTH TRADE LICENSE.
# Running a restaurant business without obtaining the Municipal Health Trade License.
# 1. the petitioner
# 1. the petitioner
# 1. the petitioner

# %%
out_df_selected = out_df[::3]
out_df_selected[900:930]
# Out:
#                                                     doc  question_id  \
# 2700  Ramakant_Gupta_vs_The_State_Of_Chhattisgarh_on...          4.1
# 2703  Ramanand_Sankhla_vs_The_State_Of_Madhya_Prades...          1.1
# 2706  Ramanand_Sankhla_vs_The_State_Of_Madhya_Prades...          2.1
# 2709  Ramanand_Sankhla_vs_The_State_Of_Madhya_Prades...          3.1
# 2712  Ramanand_Sankhla_vs_The_State_Of_Madhya_Prades...          4.1
# 2715  Raman_Yadav_vs_The_State_Of_Madhya_Pradesh_on_...          1.1
# 2718  Raman_Yadav_vs_The_State_Of_Madhya_Pradesh_on_...          2.1
# 2721  Raman_Yadav_vs_The_State_Of_Madhya_Pradesh_on_...          3.1
# 2724  Raman_Yadav_vs_The_State_Of_Madhya_Pradesh_on_...          4.1
# 2727  Raman_Yadav_vs_The_State_Of_Madhya_Pradesh_on_...          1.1
# 2730  Raman_Yadav_vs_The_State_Of_Madhya_Pradesh_on_...          2.1
# 2733  Raman_Yadav_vs_The_State_Of_Madhya_Pradesh_on_...          3.1
# 2736  Raman_Yadav_vs_The_State_Of_Madhya_Pradesh_on_...          4.1
# 2739  Rameshkumar_Narendar_Tiwari_vs_The_State_Of_Ma...          1.1
# 2742  Rameshkumar_Narendar_Tiwari_vs_The_State_Of_Ma...          2.1
# 2745  Rameshkumar_Narendar_Tiwari_vs_The_State_Of_Ma...          3.1
# 2748  Rameshkumar_Narendar_Tiwari_vs_The_State_Of_Ma...          4.1
# 2751  Ramprakash_Bhutra_vs_State_Of_Rajasthan_on_2_A...          1.1
# 2754  Ramprakash_Bhutra_vs_State_Of_Rajasthan_on_2_A...          2.1
# 2757  Ramprakash_Bhutra_vs_State_Of_Rajasthan_on_2_A...          3.1
# 2760  Ramprakash_Bhutra_vs_State_Of_Rajasthan_on_2_A...          4.1
# 2763  Ram_Anuj_Maurya_And_Another_vs_State_Of_U_P_An...          1.1
# 2766  Ram_Anuj_Maurya_And_Another_vs_State_Of_U_P_An...          2.1
# 2769  Ram_Anuj_Maurya_And_Another_vs_State_Of_U_P_An...          3.1
# 2772  Ram_Anuj_Maurya_And_Another_vs_State_Of_U_P_An...          4.1
# 2775  Ram_Babu_vs_State_Of_U_P_And_3_Others_on_12_Ma...          1.1
# 2778  Ram_Babu_vs_State_Of_U_P_And_3_Others_on_12_Ma...          2.1
# 2781  Ram_Babu_vs_State_Of_U_P_And_3_Others_on_12_Ma...          3.1
# 2784  Ram_Babu_vs_State_Of_U_P_And_3_Others_on_12_Ma...          4.1
# 2787  Ram_Chandra_Agarwal_vs_The_State_Of_Jharkhand_...          1.1
#
#                                                question  \
# 2700      What crime was associated with the food item?
# 2703       What food product was involved in this case?
# 2706  Is the petitioner individual, government entit...
# 2709  Is the respondent individual, government entit...
# 2712      What crime was associated with the food item?
# 2715       What food product was involved in this case?
# 2718  Is the petitioner individual, government entit...
# 2721  Is the respondent individual, government entit...
# 2724      What crime was associated with the food item?
# 2727       What food product was involved in this case?
# 2730  Is the petitioner individual, government entit...
# 2733  Is the respondent individual, government entit...
# 2736      What crime was associated with the food item?
# 2739       What food product was involved in this case?
# 2742  Is the petitioner individual, government entit...
# 2745  Is the respondent individual, government entit...
# 2748      What crime was associated with the food item?
# 2751       What food product was involved in this case?
# 2754  Is the petitioner individual, government entit...
# 2757  Is the respondent individual, government entit...
# 2760      What crime was associated with the food item?
# 2763       What food product was involved in this case?
# 2766  Is the petitioner individual, government entit...
# 2769  Is the respondent individual, government entit...
# 2772      What crime was associated with the food item?
# 2775       What food product was involved in this case?
# 2778  Is the petitioner individual, government entit...
# 2781  Is the respondent individual, government entit...
# 2784      What crime was associated with the food item?
# 2787       What food product was involved in this case?
#
#                                                  answer
# 2700  The petitioner was associated with selling adu...
# 2703                                     Not specified.
# 2706                                         Individual
# 2709                                  Government entity
# 2712                                     Not specified.
# 2715                                     Not specified.
# 2718                                         Individual
# 2721                                  Government entity
# 2724                                     Not specified.
# 2727                                     Not specified.
# 2730                                         Individual
# 2733                                     Not specified.
# 2736                                     Not specified.
# 2739                              Gutka and Pan Masala.
# 2742                                         Individual
# 2745                                  Government entity
# 2748  The crime associated with the food item was th...
# 2751                                      Groundnut oil
# 2754                                         Individual
# 2757                                  Government entity
# 2760     The groundnut oil was found to be substandard.
# 2763                                     Not specified.
# 2766                                         Individual
# 2769                                  Government entity
# 2772                                     Not specified.
# 2775                                               Milk
# 2778                                         Individual
# 2781                                  Government entity
# 2784                                     Not specified.
# 2787                                               Oils

# %%
# remove numbers from answer
out_df_cleaned = out_df.copy()
out_df_cleaned['answer'] = out_df['answer'].apply(lambda x: re.sub(r'\d+\. ', '', x))
out_df_cleaned
# Out:
#                                                     doc  question_id  \
# 0     Abhijeet_Suryakant_Maske_And_Anr_vs_The_State_...          1.1
# 1     Abhijeet_Suryakant_Maske_And_Anr_vs_The_State_...          1.2
# 2     Abhijeet_Suryakant_Maske_And_Anr_vs_The_State_...          1.3
# 3     Abhijeet_Suryakant_Maske_And_Anr_vs_The_State_...          2.1
# 4     Abhijeet_Suryakant_Maske_And_Anr_vs_The_State_...          2.2
# ...                                                 ...          ...
# 3022  Pritam_Kumar_Mittal_And_Ors_vs_Saurabh_Tanwar_...          4.2
# 3023  Pritam_Kumar_Mittal_And_Ors_vs_Saurabh_Tanwar_...          4.3
# 3024  Pritam_Kumar_Mittal_And_Ors_vs_Saurabh_Tanwar_...          5.1
# 3025  Pritam_Kumar_Mittal_And_Ors_vs_Saurabh_Tanwar_...          5.2
# 3026  Pritam_Kumar_Mittal_And_Ors_vs_Saurabh_Tanwar_...          5.3
#
#                                                question  \
# 0          What food product was involved in this case?
# 1     What type of food product is discussed in this...
# 2              Which food item is central to this case?
# 3     Is the petitioner 1. individual, 2. government...
# 4     What classification best describes the petitio...
# ...                                                 ...
# 3022  What unlawful act was committed involving the ...
# 3023  What crime was committed in relation to the fo...
# 3024  Was the outcome of the case in favour of 1. th...
# 3025  Whose side did the judgment favor, 1. the peti...
# 3026  Did the case outcome favor 1. the petitioner o...
#
#                                                  answer
# 0                                                    NA
# 1                                                    NA
# 2                                                    NA
# 3                                            individual
# 4                                            individual
# ...                                                 ...
# 3022  Defendant no.1 was running his food business i...
# 3023  Running a restaurant business without obtainin...
# 3024                                     the petitioner
# 3025                                     the petitioner
# 3026                                     the petitioner
#
# [3027 rows x 4 columns]

# %%
tobacco_terms = ['tobacco', 'guthka','gutka', 'pan', 'cigarette', 'smoking', 'hookah']
tobacco_out = out_df_cleaned[out_df_cleaned['answer'].str.contains('|'.join(tobacco_terms), case=False)]

# %%
#replace any answers for questions with question_id 1.1, 1.2, or 1.3,  which include tobacco_terms with 'tobacco/pan/guthka'
for answer in

# %%
list(out_df_cleaned['answer'])
# Out:
# ['NA',
#  'NA',
#  'NA',
#  'individual',
#  'individual',
#  'individual',
#  'government entity',
#  'government entity',
#  'government entity',
#  'Crime No. 53 of 2022 registered with Baramati Police Station, Dist. Pune under Section 328, 272, 273, 188 of IPC and Section 26(2)(iv), 27, 30(2), 31 and 59 of the Food Safety and Standards Act, 2006.',
#  'NA',
#  'NA',
#  'the petitioner',
#  'the petitioner',
#  'the petitioner',
#  'mixed milk',
#  'mixed milk',
#  'mixed milk',
#  'individual',
#  'individual',
#  'individual',
#  'government entity',
#  'government entity',
#  'government entity',
#  'unsafe food',
#  'The sample of mixed milk was found to be substandard and unsafe.',
#  'The sample of mixed milk was found to be substandard and unsafe.',
#  'the petitioner',
#  'the petitioner',
#  'the petitioner',
#  'Sago',
#  'Sago',
#  'Sago',
#  'organization',
#  'organization',
#  '1',
#  'government entity',
#  'government entity',
#  'government entity',
#  'NA',
#  'NA',
#  'NA',
#  'the petitioner',
#  'the petitioner',
#  'the petitioner',
#  'NA',
#  'NA',
#  'NA',
#  'individual',
#  'individual',
#  'individual',
#  'government entity',
#  'government entity',
#  'government entity',
#  'Crime No. 34 of 2022 under Section 272, 273, 328 read with Section 34 of IPC and Section 26 (2) (i), 26(2)(iv) and 59 of the Food Safety and Standards Act, 2006.',
#  'NA',
#  'NA',
#  'the petitioner',
#  'the petitioner',
#  'the petitioner',
#  'NA',
#  'NA',
#  'NA',
#  'individual',
#  'individual',
#  'individual',
#  'government entity',
#  'government entity',
#  'government entity',
#  'NA',
#  'NA',
#  'NA',
#  'the respondent',
#  'the respondent',
#  'the respondent',
#  'NA',
#  'NA',
#  'NA',
#  'individual',
#  'individual',
#  'individual',
#  'government entity',
#  'government entity',
#  'government entity',
#  'Crime No. 53 of 2022 registered with Baramati Police Station, Dist. Pune under Section 328, 272, 273, 188 of IPC and Section 26(2)(iv), 27, 30(2), 31 and 59 of the Food Safety and Standards Act, 2006.',
#  'NA',
#  'NA',
#  'the petitioner',
#  'the petitioner',
#  'the petitioner',
#  'mixed milk',
#  'mixed milk',
#  'mixed milk',
#  'individual',
#  'individual',
#  'individual',
#  'government entity',
#  'government entity',
#  'government entity',
#  'unsafe food',
#  'The sample of mixed milk was found to be substandard and unsafe.',
#  'The sample of mixed milk was found to be substandard and unsafe.',
#  'the petitioner',
#  'the petitioner',
#  'the petitioner',
#  'Sago',
#  'Sago',
#  'Sago',
#  'organization',
#  'organization',
#  '1',
#  'government entity',
#  'government entity',
#  'government entity',
#  'NA',
#  'NA',
#  'NA',
#  'the petitioner',
#  'the petitioner',
#  'the petitioner',
#  'NA',
#  'NA',
#  'NA',
#  'individual',
#  'individual',
#  'individual',
#  'government entity',
#  'government entity',
#  'government entity',
#  'Crime No. 34 of 2022 under Section 272, 273, 328 read with Section 34 of IPC and Section 26 (2) (i), 26(2)(iv) and 59 of the Food Safety and Standards Act, 2006.',
#  'NA',
#  'NA',
#  'the petitioner',
#  'the petitioner',
#  'the petitioner',
#  'NA',
#  'NA',
#  'NA',
#  'individual',
#  'individual',
#  'individual',
#  'government entity',
#  'government entity',
#  'government entity',
#  'NA',
#  'NA',
#  'NA',
#  'the respondent',
#  'the respondent',
#  'the respondent',
#  'tobacco/pan/guthka',
#  'tobacco/pan/guthka',
#  'tobacco/pan/guthka',
#  'individual',
#  'individual',
#  'individual',
#  'government entity',
#  'government entity',
#  'government entity',
#  'tobacco/pan/guthka',
#  'tobacco/pan/guthka',
#  'tobacco/pan/guthka',
#  'the petitioner',
#  'the petitioner',
#  'the petitioner',
#  'NA',
#  'NA',
#  'NA',
#  'individual',
#  'individual',
#  'individual',
#  'government entity',
#  'government entity',
#  'government entity',
#  'NA',
#  'NA',
#  'NA',
#  'the respondent',
#  'the respondent',
#  'the respondent',
#  'NA',
#  'NA',
#  'NA',
#  'organization',
#  'organization',
#  'organization',
#  'government entity',
#  'government entity',
#  'government entity',
#  'offence punishable under Section 57 of the Food Safety and Standards Act, 2006',
#  'NA',
#  'offence punishable under Section 57 of the Food Safety and Standards Act, 2006',
#  'the petitioner',
#  'the petitioner',
#  'the petitioner',
#  'tobacco/pan/guthka',
#  'tobacco/pan/guthka',
#  'tobacco/pan/guthka',
#  'individual',
#  'individual',
#  'individual',
#  'government entity',
#  'government entity',
#  'government entity',
#  'tobacco/pan/guthka',
#  'tobacco/pan/guthka',
#  'tobacco/pan/guthka',
#  'the respondent',
#  'the respondent',
#  'the respondent',
#  'NA',
#  'NA',
#  'NA',
#  'individual',
#  'individual',
#  'individual',
#  'government entity',
#  'government entity',
#  'government entity',
#  'Crime No.154 of 2021 registered with Aurad Shahajani Police Station, District Latur for the offences punishable under Sections 328, 272, 273 and 188 of Indian Penal Code and Sections 59(2)(i)(ii)(iv), 30(2)(a) and 59 of the Food Safety and Standards Act, 2006.',
#  'Possession of banned articles',
#  'The offences punishable under Sections 328, 272, 273 and 188 of Indian Penal Code and Sections 59(2)(i)(ii)(iv), 30(2)(a) and 59 of the Food Safety and Standards Act, 2006.',
#  'the petitioner',
#  'the petitioner',
#  'the petitioner',
#  'tobacco/pan/guthka',
#  'tobacco/pan/guthka',
#  'tobacco/pan/guthka',
#  'individual',
#  'individual',
#  'individual',
#  'government entity',
#  'government entity',
#  'government entity',
#  'tobacco/pan/guthka',
#  'tobacco/pan/guthka',
#  'tobacco/pan/guthka',
#  'the petitioner',
#  'the petitioner',
#  'the petitioner',
#  'tobacco/pan/guthka',
#  'tobacco/pan/guthka',
#  'tobacco/pan/guthka',
#  'individual',
#  'individual',
#  'individual',
#  'government entity',
#  'government entity',
#  'government entity',
#  'adulterated, substandard, misbranded and unsafe',
#  'The products were adulterated, substandard, misbranded and unsafe.',
#  'The products were adulterated, substandard, misbranded and unsafe.',
#  'the respondent',
#  'the respondent',
#  'the respondent',
#  'chili powder',
#  'chili powder',
#  'chili powder',
#  'individual',
#  'individual',
#  'individual',
#  'government entity',
#  'government entity',
#  'government entity',
#  'unsafe for human consumption',
#  'Unsafe for human consumption',
#  'unsafe for human consumption',
#  'the respondent',
#  'the respondent',
#  'the respondent',
#  'mineral water',
#  'mineral water',
#  'mineral water',
#  'individual',
#  'individual',
#  'individual',
#  'government entity',
#  'government entity',
#  'government entity',
#  'Offences punishable under Sections 2(1a) (m), 7(1), 16(1) (a) of Prevention of Food Adulteration Act.',
#  'The mineral water did not conform to the standards prescribed.',
#  'Offences punishable under Sections 2(1a) (m), 7(1), 16(1) (a) of Prevention of Food Adulteration Act.',
#  'the petitioner',
#  'the petitioner',
#  'the petitioner',
#  'NA',
#  'NA',
#  'NA',
#  'individual',
#  'individual',
#  'individual',
#  'government entity',
#  'government entity',
#  'government entity',
#  'NA',
#  'NA',
#  'NA',
#  'the respondent',
#  'the respondent',
#  'the respondent',
#  'NA',
#  'NA',
#  'NA',
#  'individual',
#  'individual',
#  'individual',
#  'government entity',
#  'government entity',
#  'government entity',
#  'NA',
#  'NA',
#  'NA',
#  'the petitioner',
#  'the petitioner',
#  'the petitioner',
#  'NA',
#  'NA',
#  'NA',
#  'individual',
#  'individual',
#  'NA',
#  'government entity',
#  'government entity',
#  'government entity',
#  'Sections 270, 273, 420 IPC and Sections 56, 57(1), 63 of the Food Safety and Standards Act, 2006',
#  'NA',
#  'Offences punishable under Sections 270, 273, 420 IPC and under Sections 56, 57(1), 63 of the Food Safety and Standards Act, 2006.',
#  'the petitioner',
#  'the petitioner',
#  'the petitioner',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'the petitioner',
#  'the petitioner',
#  'the petitioner',
#  'tobacco/pan/guthka',
#  'tobacco/pan/guthka',
#  'tobacco/pan/guthka',
#  'individual',
#  'individual',
#  'NA',
#  'government entity',
#  'government entity',
#  'government entity',
#  'tobacco/pan/guthka',
#  'NA',
#  'NA',
#  'the petitioner',
#  'the petitioner',
#  'the petitioner',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'the petitioner',
#  'the petitioner',
#  'the petitioner',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'government entity',
#  'government entity',
#  'government entity',
#  'NA',
#  'NA',
#  'NA',
#  'the petitioner',
#  'the petitioner',
#  'the petitioner',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'government entity',
#  'government entity',
#  'NA',
#  'NA',
#  'NA',
#  'the petitioner',
#  'the petitioner',
#  'the petitioner',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'individual',
#  'NA',
#  'NA',
#  'government entity',
#  'government entity',
#  'NA',
#  'NA',
#  'NA',
#  'the petitioner',
#  'the petitioner',
#  'the petitioner',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'government entity',
#  'government entity',
#  'NA',
#  'NA',
#  'NA',
#  'the petitioner',
#  'the petitioner',
#  'the petitioner',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'individual',
#  'NA',
#  'NA',
#  'government entity',
#  'government entity',
#  'NA',
#  'NA',
#  'NA',
#  'the petitioner',
#  'the petitioner',
#  'the petitioner',
#  'tobacco/pan/guthka',
#  'tobacco/pan/guthka',
#  'tobacco/pan/guthka',
#  'NA',
#  'NA',
#  'NA',
#  'government entity',
#  'government entity',
#  'government entity',
#  'NA',
#  'NA',
#  'NA',
#  'the petitioner',
#  'the petitioner',
#  'the petitioner',
#  'tobacco/pan/guthka',
#  'tobacco/pan/guthka',
#  'tobacco/pan/guthka',
#  'NA',
#  'NA',
#  'NA',
#  'government entity',
#  'government entity',
#  'government entity',
#  'tobacco/pan/guthka',
#  'NA',
#  'NA',
#  'the petitioner',
#  'the petitioner',
#  'the petitioner',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'government entity',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'the petitioner',
#  'the petitioner',
#  'the petitioner',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'government entity',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'the petitioner',
#  'the petitioner',
#  'the petitioner',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'government entity',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'the petitioner',
#  'the petitioner',
#  'the petitioner',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'government entity',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'the petitioner',
#  'the petitioner',
#  'the petitioner',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'the petitioner',
#  'the petitioner',
#  'the petitioner',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'the petitioner',
#  'the petitioner',
#  'the petitioner',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'the petitioner',
#  'the petitioner',
#  'the petitioner',
#  'NA',
#  'tobacco/pan/guthka',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'the petitioner',
#  'the petitioner',
#  'the petitioner',
#  'NA',
#  'tobacco/pan/guthka',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'the petitioner',
#  'the petitioner',
#  'the petitioner',
#  'NA',
#  'tobacco/pan/guthka',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'the petitioner',
#  'the petitioner',
#  'the petitioner',
#  'NA',
#  'tobacco/pan/guthka',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'the petitioner',
#  'the petitioner',
#  'the petitioner',
#  'NA',
#  'tobacco/pan/guthka',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'the petitioner',
#  'the petitioner',
#  'the petitioner',
#  'NA',
#  'tobacco/pan/guthka',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'the petitioner',
#  'the petitioner',
#  'the petitioner',
#  'NA',
#  'tobacco/pan/guthka',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'the petitioner',
#  'the petitioner',
#  'the petitioner',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'government entity',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'the petitioner',
#  'the petitioner',
#  'the petitioner',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'government entity',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'the petitioner',
#  'the petitioner',
#  'the petitioner',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'government entity',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'the petitioner',
#  'the petitioner',
#  'the petitioner',
#  'Laddu',
#  'Laddu',
#  'Laddu',
#  'individual',
#  'individual',
#  'government entity',
#  'individual',
#  'individual',
#  'individual',
#  'unsafe food due to excessive artificial food colouring matter',
#  'The food item contained added artificial colouring matter to the tune of total 334.36 ppm, which is beyond the maximum prescribed limit of 100 ppm and is unsafe for human consumption.',
#  'The food item was unsafe due to excessive artificial food coloring matter exceeding the maximum prescribed limit.',
#  'the respondent',
#  'the respondent',
#  'the respondent',
#  'REAL Mixed Fruit Juice',
#  'fruit juice/beverages',
#  'REAL Mixed Fruit Juice',
#  'organization',
#  'organization',
#  'organization',
#  'individual',
#  'individual',
#  'individual',
#  'Defamation/disparagement',
#  "The impugned video was disparaging to the plaintiff's products and contained false and incorrect information, misleading consumers about the health effects of the plaintiff's REAL Mixed Fruit Juice.",
#  'Defamation/disparagement',
#  'the petitioner',
#  'the petitioner',
#  'the petitioner',
#  'tobacco/pan/guthka',
#  'tobacco/pan/guthka',
#  'paan masala',
#  'individual',
#  'individual',
#  'individual',
#  'government entity',
#  'government entity',
#  'government entity',
#  'tobacco/pan/guthka',
#  'tobacco/pan/guthka',
#  'tobacco/pan/guthka',
#  'the respondent',
#  'the respondent',
#  'the respondent',
#  'NA',
#  'NA',
#  'NA',
#  'organization',
#  'organization',
#  'organization',
#  'government entity',
#  'government entity',
#  'government entity',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'tobacco/pan/guthka',
#  'tobacco/pan/guthka',
#  'tobacco/pan/guthka',
#  'organization',
#  'organization',
#  'organization',
#  'government entity',
#  'government entity',
#  'government entity',
#  'Manufacture, storage, distribution or sale of prohibited food items.',
#  'tobacco/pan/guthka',
#  'tobacco/pan/guthka',
#  'the petitioner',
#  'the petitioner',
#  'the petitioner',
#  'Gutkha',
#  'Gutkha',
#  'Gutkha',
#  'individual',
#  'individual',
#  'individual',
#  'government entity',
#  'government entity',
#  'government entity',
#  'Gutkha',
#  'The unlawful act involved the storage and distribution of Gutkha, which is banned in Maharashtra.',
#  'Gutkha was stored in violation of the Food Safety and Standards Act, 2006.',
#  'the petitioner',
#  'the petitioner',
#  'the petitioner',
#  'tobacco/pan/guthka',
#  'tobacco/pan/guthka',
#  'tobacco/pan/guthka',
#  'individual',
#  'individual',
#  'individual',
#  'government entity',
#  'government entity',
#  'government entity',
#  'tobacco/pan/guthka',
#  'tobacco/pan/guthka',
#  'tobacco/pan/guthka',
#  'the petitioner',
#  'the petitioner',
#  'the petitioner',
#  'tobacco/pan/guthka',
#  'tobacco/pan/guthka',
#  'tobacco/pan/guthka',
#  'individual',
#  'individual',
#  'individual',
#  'government entity',
#  'government entity',
#  'government entity',
#  'tobacco/pan/guthka',
#  'tobacco/pan/guthka',
#  'tobacco/pan/guthka',
#  'the respondent',
#  'the respondent',
#  'the respondent',
#  'NA',
#  'NA',
#  'NA',
#  'individual',
#  'individual',
#  'individual',
#  'government entity',
#  'government entity',
#  'government entity',
#  'The alleged commission of offence under Sections 420/272/273/34 of IPC read with Sections 52/53/56/57/59/63 of Food Safety and Standard Act, 2006 and Section 16 of Prevention of Food Adulteration Act, 1954.',
#  'NA',
#  'NA',
#  'the petitioner',
#  'the petitioner',
#  'the petitioner',
#  'NA',
#  'NA',
#  'NA',
#  'individual',
#  'individual',
#  'individual',
#  'government entity',
#  'government entity',
#  'government entity',
#  'NA',
#  'NA',
#  'NA',
#  'the respondent',
#  'the respondent',
#  'the respondent',
#  'tobacco/pan/guthka',
#  'tobacco/pan/guthka',
#  'tobacco/pan/guthka',
#  'individual',
#  'individual',
#  'individual',
#  'government entity',
#  'government entity',
#  'government entity',
#  'NA',
#  'tobacco/pan/guthka',
#  'NA',
#  'the petitioner',
#  'the petitioner',
#  'the petitioner',
#  'tobacco/pan/guthka',
#  'tobacco/pan/guthka',
#  'tobacco/pan/guthka',
#  'individual',
#  'individual',
#  'individual',
#  'government entity',
#  'government entity',
#  'government entity',
#  'Prohibited articles worth Rs.17,800/- were recovered.',
#  'Prohibited articles worth Rs.17,800/- were recovered.',
#  'Prohibited articles worth Rs.17,800/- were recovered.',
#  'the petitioner',
#  'the petitioner',
#  'the petitioner',
#  'NA',
#  'NA',
#  'NA',
#  'organization',
#  'organization',
#  'organization',
#  'government entity',
#  'government entity',
#  'government entity',
#  'NA',
#  'NA',
#  'NA',
#  'the petitioner',
#  'the petitioner',
#  'the petitioner',
#  'ghee',
#  'ghee',
#  'ghee',
#  'individual',
#  'individual',
#  'individual',
#  'government entity',
#  'government entity',
#  'government entity',
#  'sub-standard food article namely ghee',
#  'sale of sub-standard food articles',
#  'sub-standard food articles',
#  'the petitioner',
#  'the petitioner',
#  'the petitioner',
#  'fruits',
#  'fruits',
#  'fruits',
#  'individual',
#  'organization',
#  'individual',
#  'organization',
#  'government entity',
#  'organization',
#  'NA',
#  'NA',
#  'NA',
#  'the respondent',
#  'the respondent',
#  'the respondent',
#  'NA',
#  'NA',
#  'NA',
#  'individual',
#  'individual',
#  'individual',
#  'government entity',
#  'government entity',
#  'government entity',
#  'NA',
#  'NA',
#  'NA',
#  'the petitioner',
#  'the petitioner',
#  'the petitioner',
#  'NA',
#  'NA',
#  'NA',
#  'individual',
#  'individual',
#  'individual',
#  'government entity',
#  'government entity',
#  'government entity',
#  'NA',
#  'NA',
#  'NA',
#  'the petitioner',
#  'the petitioner',
#  'the petitioner',
#  'NA',
#  'NA',
#  'NA',
#  'individual',
#  'individual',
#  'individual',
#  'government entity',
#  'government entity',
#  'government entity',
#  'NA',
#  ...]
