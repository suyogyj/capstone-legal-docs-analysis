# %%
from legal_NER.ner_extraction_functions import tag_docs, read_pdf, extract_statutes_provisions_precedents
import pandas as pd
import os
from spacy import displacy
from tqdm import tqdm
import time

# %%
openai_extracted = pd.read_csv('openai_extracted.csv', index_col=0)
openai_extracted.columns
# Out:
# Index(['file_name', 'summary', 'court', 'petitioners', 'respondents', 'judges',
#        'date', 'org', 'gpe', 'provisions', 'statutes', 'precedents',
#        'key_facts', 'type_of_case', 'decision'],
#       dtype='object')

# %%
text = read_pdf('Docs/food-safety/Amluya_Anand_vs_State_on_8_March_2022.PDF')
doc = tag_docs(text)

# %%
done_df = pd.read_csv('ner_extracted.csv', index_col=0)

out_df = pd.DataFrame(columns=['filename', 'error', 'court', 'petitioners', 'respondents', 'judges', 'date', 'org', 'gpe', 'provisions', 'statutes', 'precedents'])

def save_output_to_df(df, filename, error, court, petitioners, respondents, judges, date, org, gpe, provisions, statutes, precedents):
    df.loc[len(df)] = [filename, error, court, petitioners, respondents, judges, date, org, gpe, provisions, statutes, precedents]
    return df

# %%
done_df
# Out:
#                                             file_name  \
# 0   Abhijeet_Suryakant_Maske_And_Anr_vs_The_State_...
# 1           Amluya_Anand_vs_State_on_8_March_2022.PDF
# 2   Arulmurugan_Starch_Industries_vs_Food_Safety_A...
# 3   Arun_Raosaheb_Khot_vs_State_Of_Maharashtra_on_...
# 4   Asha_Singh_vs_The_State_Of_Bihar_on_24_March_2...
# ..                                                ...
# 60  Gyanaduttachouhan_vs_The_Additional_Chief_Secr...
# 61  G_Sudheeshkumar_vs_State_Of_Kerala_on_15_Febru...
# 62  Haldiram_Bhujiawala_Limited_vs_The_State_Of_Jh...
# 63  High_Court_On_Its_Own_Motion_In_The_vs_Bhiwand...
# 64  Imran_Shamshad_Ansari_vs_The_State_Of_Maharash...
#
#                                                 court  \
# 0   ['High Court Of Judicature At Bombay', 'Suprem...
# 1   ['High Court Of Judicature For Rajasthan At\n ...
# 2              ['High Court Of Judicature At Madras']
# 3   ['High Court Of Judicature At Bombay', 'Suprem...
# 4   ['High Court Of Judicature At Patna', 'Patna H...
# ..                                                ...
# 60  ['High Court Of Orissa At Cuttack', 'Collector...
# 61              ['High Court Of Kerala At Ernakulam']
# 62  ['High Court Of Jharkhand At Ranchi', 'Collect...
# 63  ['High Court Of Judicature At Bombay', 'Suprem...
# 64             ['High Court Of Judicature At Bombay']
#
#                                           petitioners  \
# 0   ['Abhijeet Suryakant Maske', 'Abhijeet Suryaka...
# 1                    ['Amluya Anand', 'Amluya Anand']
# 2   ['Arulmurugan Starch Industries', '2018Arulmur...
# 3   ['Arun Raosaheb Khot', 'Sneha\nNitin', 'Arun R...
# 4                        ['Asha Singh', 'Asha Singh']
# ..                                                ...
# 60  ['Gyanaduttachouhan', 'GyanaduttaChouhan', 'Gy...
# 61  ['G.Sudheeshkumar', 'G.Sudheeshkumar', '2G.Sud...
# 62  ['Haldiram Bhujiawala Limited', 'Kailash Prasa...
# 63  ['LEGISLATION PROVISIONS PUBLIC PENAL PROVISIO...
# 64  ['Imran Shamshad Ansari', 'Sneha\nNitin\nChava...
#
#                                           respondents judges  \
# 0   ['State Of Maharashtra', 'State of Maharashtra...     []
# 1                                  ['State', 'State']     []
# 2   ['Food Safety And Standards', 'Commissioner of...     []
# 3    ['State Of Maharashtra', 'State of Maharashtra']     []
# 4   ['State Of Bihar', 'State of Bihar', 'Union Of...     []
# ..                                                ...    ...
# 60  ['Additional Chief Secretary To', 'Additional ...     []
# 61  ['State Of Kerala', 'P.V.Kunhikrishnan', 'Stat...     []
# 62       ['State Of Jharkhand', 'State of Jharkhand']     []
# 63  ['Bhiwandi Nizampur', 'Bhiwandi Nizampur Munic...     []
# 64   ['State Of Maharashtra', 'State of Maharashtra']     []
#
#                                                  date  \
# 0   ['1 March, 2022', '6 November 2020', '21 Septe...
# 1   ['08/03/2022', '17/02/2022', '07.04.2015', '24...
# 2   ['11.7.2018', '19.01.2022', '19 January, 2022'...
# 3   ['31 January, 2022', '6 November 2020', '21 Se...
# 4   ['24-03-2022', 'dt.24-03-2022', '24 March, 202...
# ..                                                ...
# 60  ['7th July 2021', '23rd May, 2021', '23 March,...
# 61  ['15th day of February, 2022', '2.4.12', '20.7...
# 62  ['27.07.2018', '2.2.2.2', '2.2.2.8', '2.2.2.7'...
# 63  ['26 February, 2022', 'September 24, 2020', '9...
# 64  ['25 January, 2022', '30.09.2021', '18.02.2022...
#
#                                                   org  \
# 0   ['Baramati Police Station, Dist', 'Baramati Po...
# 1   ['Swastik Milk Chilling Centre', 'Amul Dairy',...
# 2    ['Food Safety and Standards Authority of India']
# 3          ['Police Station Hadapsar, District Pune']
# 4   ['C.B.I.', 'Tata Institute of Social Sciences'...
# ..                                                ...
# 60  ['Veer SurendraSai Instituteof Medical Science...
# 61                         ['ADV GOVERNMENT PLEADER']
# 62  ['Haldiram Bhujiawala Limited', 'State Food an...
# 63  ['TMC', 'MMRDA', 'Bhiwandi Nizampur Municipal ...
# 64                                                 []
#
#                                                   gpe provisions statutes  \
# 0                ['Pune', 'Mumbai', 'Mumbai', 'Pune']         []       []
# 1   ['Nagaur', 'Thanwla District Nagaur', 'Jodhpur...         []       []
# 2   ['New Delhi', 'Chennai', 'Salem District', 'Sa...         []       []
# 3                                ['Mumbai', 'Mumbai']         []       []
# 4   ['Turkauliya', 'Raghunathpur', 'Motihari', 'Bi...         []       []
# ..                                                ...        ...      ...
# 60  ['Kendbahal', 'Bargarh District', 'Orissa', 'O...         []       []
# 61                                                 []         []       []
# 62                               ['Bokaro', 'Ranchi']         []       []
# 63  ['Bhiwandi', 'Mumbai', 'Mumbai', 'Mumbai Metro...         []       []
# 64                           ['Aurangabad', 'Mumbai']         []       []
#
#    precedents
# 0          []
# 1          []
# 2          []
# 3          []
# 4          []
# ..        ...
# 60         []
# 61         []
# 62         []
# 63         []
# 64         []
#
# [65 rows x 11 columns]

# %%
failed = []
for filename in tqdm(openai_extracted.file_name):
    if filename in out_df.filename.values:
        continue
    try:
        provisions, statutes, precedents = [], [], []
        error = "NA"
        text = read_pdf('Docs/food-safety/' + filename)
        doc = tag_docs(text)
        try:
            provisions, statutes, precedents = extract_statutes_provisions_precedents(doc)
        except Exception as e: 
            print(f"Error encountered while processing file {filename}: {e}")  
            error = e
            provisions = [ent.text for ent in doc.ents if ent.label_ == 'PROVISION']
            statutes = [ent.text for ent in doc.ents if ent.label_ == 'STATUTE']
            precedents = [ent.text for ent in doc.ents if ent.label_ == 'PRECEDENT']
            print(f"Provisions: {provisions}, Statutes: {statutes}, Precedents: {precedents}")
            
        orgs = [ent.text for ent in doc.ents if ent.label_ == 'ORG']
        gpes = [ent.text for ent in doc.ents if ent.label_ == 'GPE']
        judges = [ent.text for ent in doc.ents if ent.label_ == 'JUDGE']
        petitioners = [ent.text for ent in doc.ents if ent.label_ == 'PETITIONER']
        respondents = [ent.text for ent in doc.ents if ent.label_ == 'RESPONDENT']
        court = [ent.text for ent in doc.ents if ent.label_ == 'COURT']
        date = [ent.text for ent in doc.ents if ent.label_ == 'DATE']
        out_df = save_output_to_df(out_df, filename, error, court, petitioners, respondents, judges, date, orgs, gpes, provisions, statutes, precedents)
        out_df.to_csv('ner_extracted_2.csv')
    except Exception as e:
        print(f"Error encountered while processing file {filename}: {e}")
        failed.append(filename)
        continue
# Out:
#  82%|████████▏ | 160/196 [00:10<00:02, 14.92it/s]
# Error encountered while processing file Satish_Murari_Lal_Sharma_vs_The_State_Of_Maharashtra_on_22_March_2022.PDF: 'NoneType' object has no attribute 'vocab'
#  87%|████████▋ | 171/196 [04:28<07:41, 18.46s/it]
# ⚠ There was some issue while performing postprocessing, skipping
# postprocessing...
# Error encountered while processing file Smt_C_Kavitha_vs_Sri_Sivanesan_P_on_19_March_2022.PDF: 'provision_statute_pairs'
# Provisions: ['Sec.29', 'Sec.12', 'Sec.125', 'Sec.12', 'Sec.125', 'Sec.12', 'Sec.125', 'Sec.3 explanation 4', 'Sec.12', 'Sec.2(a)', 'Sec.2(f)', 'Sec.2(f)', 'Sec.3', 'Sec.3', 'clause (a) or clause (h); or (d)', 'Sec.3', 'Sec.3', 'Sec.2(f)', 'Sec.17 to Sec.22', 'Sec.20', 'Sec.31', 'Sec.31', 'Sec.31', 'Sec.31', 'Sec.12', 'section 468', 'Sec.12', 'Sec.20 and 21', 'Sec.2(a)', 'Sec.12', 'Sec.12', 'Sec.12', 'Sec.12', 'Sec.12', 'Sec.20', 'Sec.12(1)', 'Sec.125', 'Sec.20(2)', 'Sec.20', 'Sec.29', 'Sec.29'], Statutes: ['Protection of Women from Domestic Violence Act,\n2005', 'Protection of Women from Domestic Violence Act, 2005', 'Cr.', 'Protection of Women from Domestic Violence Act,\n2005', 'Cr.', 'Protection of Women from Domestic Violence Act, 2005', 'Cr', 'Protection of Women from Domestic Violence Act, 2005', 'Protection of Women from Domestic Violence Act, 2005', 'Domestic Violence Act', 'PWDV Act', 'Protection of Women from Domestic Violence Act', 'Protection of Women from Domestic Violence Act', 'Protection of Women from Domestic Violence Act', 'Protection of Women from Domestic Violence Act', 'Cr.P.C.', 'Protection of Women from Domestic Violence Act', 'Protection of Women from Domestic Violence Act', 'Protection of Women from Domestic Violence Act', 'Protection of Women from Domestic Violence Act', 'Protection of Women from Domestic Violence Act', 'D.V. Act', 'Cr.', 'Domestic Violence Act', 'Domestic Violated Act', 'Protection of Women from Domestic Violence Act', 'Protection of Women from Domestic Violence Act', 'Protection of Women from Domestic Violence Act', 'Protection of Women from Domestic Violence Act', 'Protection of Women from Domestic Violence Act', 'Protection of Women from Domestic Violence Act', 'Protection of Women from Domestic Violence Act', 'Protection of Women from Domestic Violence Act', 'Cr.P.C.', 'Protection of Women from Domestic Violence Act', 'Protection of Women Crl', 'Domestic Violence Act, 2005', 'Protection of Women from Domestic Violence Act, 2005'], Precedents: ['C.Kavitha vs Sri', 'C.Kavitha vs Sri', 'C.Kavitha vs Sri', 'C.Kavitha vs Sri', 'C.Kavitha vs Sri', 'C.Kavitha vs Sri', 'C.Kavitha vs Sri', 'C.Kavitha vs Sri', '2021 (3) AKR 862, AIR online 2021 Karnataka 1052 (Shahida V/s Abubakkar and another)', 'V.Nagarajan and others V/s.\nB.P.Thangaveni', 'Puttaraju V/s Shivakumari', 'C.Kavitha vs Sri', 'Krishna Bhattacharjee V/s Sarathi Choudari (2016) (2)\nSCC 705', 'Anthony Jose V/s State (NCT of Delhi)', 'C.Kavitha vs Sri', 'C.Kavitha vs Sri', 'C.Kavitha vs Sri', 'C.Kavitha vs Sri']
#  90%|████████▉ | 176/196 [06:58<07:35, 22.75s/it]
# ⚠ There was some issue while performing postprocessing, skipping
# postprocessing...
# Error encountered while processing file State_Of_Gujarat_On_Behalf_Of_Amratbhai_vs_Ramsinh_Durgsinh_Rajpurohit_on_9_March_2022.PDF: 'provision_statute_pairs'
# Provisions: ['Sections 26(1), 26(2)(I),\n', '26(2)(5), 27 and 59', 'No.2.12.(1)(2)'], Statutes: ['Food Safety & Standard Act, 2006', 'Food Product Standard & Food R/CR.MA/21745/2021'], Precedents: ['State Of Gujarat On Behalf Of Amratbhai ... vs Ramsinh\nDurgsinh Rajpurohit']
#  93%|█████████▎| 183/196 [08:13<02:17, 10.56s/it]
# Error encountered while processing file S_P_Shrivastava_vs_The_State_Of_Madhya_Pradesh_on_21_January_2022.PDF: 'NoneType' object has no attribute 'vocab'
#  96%|█████████▋| 189/196 [23:32<18:04, 154.94s/it]
# ⚠ There was some issue while performing postprocessing, skipping
# postprocessing...
# Error encountered while processing file The_Swedish_Club_vs_V8_Pool_Inc_And_3_Ors_on_23_March_2022.PDF: 'provision_statute_pairs'
# Provisions: ['Rule 1084', 'Rule 1084', 'Regulation 2.5, paragraph 2', 'Regulation 5.1.3', 'Appendix A2-I.', 'Regulations 2.2 and 2.5', 'Regulation 12 of Standard A2.5.2', 'Rule 1084', 'Rule 1084', 'Regulation 12 of A2.5.2', 'Aquarius III', 'Rule 1084', 'Section 9(1)(a) r/w Section 10(1)(a)', 'Rule 1084', 'Rule 1084', 'Rule 1084', 's. 93(1)', 'clause 12 of Standard A2.5.2', 'Rule 1084', 'Rule 1084', 'Rule 1084', 'Rule 1084', 'clause 12 of A2.5.2'], Statutes: ['Maritime Labour Convention, 2006', 'Maritime Labour Convention', 'Bombay High Court (Original Side) Rules', 'Maritime Labour Convention', 'Maritime Labour Convention', 'MLC', 'Admiralty ( Jurisdiction and Settlement of Maritime Claims) Act, 2017', 'MLC', 'MLC', 'MLC'], Precedents: ['Swedish Club vs V8 Pool Inc.', 'Swedish Club vs V8 Pool Inc.', 'Swedish Club vs V8 Pool Inc.', 'Swedish Club vs V8 Pool Inc.', 'Swedish Club vs V8 Pool Inc.', "Leoborg, [1964] 1 Lloyd's Rep 380", "Vasilia, [1972] 1 Lloyd's Rep 51", "Berostar, [1970] 2 Lloyd's Rep 403", 'Swedish Club vs V8 Pool Inc.', 'Axis Trustees Service Ltd v. MT Prem Mala', 'Irwin Edmond Sequeira v mv Karnika', 'DVB Group Merchant Bank (Asia) Ltd v mv Malaviya Twenty Three & Ors', 'Irwin Edmond Sequeira v m.v. Karnika (Colabawalla, J.)', 'Aquarius III, [2002] SGHC 138', 'Credit Suisse v. Brightoil Lion', 'Credit Suisse v. Brightoil Lion', 'Swedish Club vs V8 Pool Inc.', 'Axis Trustees Service Ltd v. MT Prem Mala', 'Slovesnov Vadym v. OSV Beas Dolphin', 'Aviat Chemicals Pvt ltd v Jagmohansingh Arora (2000)', 'Bom Cr 90 (Nijjar, J.) d. Navios Corporation v. mv Fu Jin', 'Det Norske Veritas v. m.t. PRATIBHA INDRAYANI', 'Indian Register of Shipping v. m.t', 'Swedish Club vs V8 Pool Inc.', 'Madison Pacific Trust Limited v MV Garv Prem', 'Madison Pacific Trust Limited v MV Garv Prem', 'Sarfuddin Davar v.M.V. Don Jose & Ors', '[[1998] C.L.C.\n1043]', 'Coromandel International Ltd. v. m.v', 'Patrick Stevedores No. 2 Pty. Ltd. v. Tukarina, (1998) 154 ALR 514', 'Ltd. v. m.v', 'Swedish Club vs V8 Pool Inc.', "[2000] Vol. 2 Lloyd's Rep 618 [H.K. Ct.]", 'Coromandel International Ltd. v. m.v', 'Patrick Stevedores No. 2 Pty. Ltd. v. Tukarina, (1998) 154 ALR 514-', 'Ltd. v. m.v', 'Swedish Club vs V8 Pool Inc.', 'Swedish ClubThe Swedish Club vs V8 Pool Inc.', 'Swedish Club vs V8 Pool Inc.', 'Swedish Club vs V8 Pool Inc.', 'Swedish Club vs V8 Pool Inc.', 'Swedish Club vs V8 Pool Inc.', 'Swedish Club vs V8 Pool Inc.', 'Swedish Club vs V8 Pool Inc.']
#  98%|█████████▊| 192/196 [25:46<05:21, 80.35s/it]
# ⚠ There was some issue while performing postprocessing, skipping
# postprocessing...
# Error encountered while processing file Vijaysing_Dnyaneshwar_Gotya_S_O_vs_State_Of_Mha_Thr_Officer_In_Charge_Of_Ps_on_13_January_2022.PDF: 'provision_statute_pairs'
# Provisions: ['Sections 188, 272, 273, 328', 'Sections 26(2)(i), 26(2)', '(iv), 26(2)(v), 27(2)(e), 30(2)(a) and 59', 'Section 328', 'C.R. 492', 'Section 328', 'Sec 26(2)(i), 26(2)(v), 26(2)(iv), 27(2)(e),\n', 'Section 328', 'Section 328', 'Sections 26(2)(i), 26(2)(v),\n26(2)(iv), 27(2)(e), 30(2)(e)'], Statutes: ['IPC', 'Food Safety and Standard Act 2006', 'IPC', 'IPC', 'Food Safety and Standard Act, 2006', 'IPC', 'IPC', 'oral squamous cell carcinoma', 'Cigarettes and other Tobacco Products Act 2003', 'Food Safety & Standard Act, 2006'], Precedents: ['Vijaysing @ Dnyaneshwar @ Gotya S/O ... vs State Of Mha', 'Ganesh Pandurang Jadhao vrs', 'Union of India and others vrs', 'Unicorn Industries; (2019) 10 SCC 575', 'Unicorn Industries', 'beenVijaysing @ Dnyaneshwar @ Gotya S/O ... vs State Of Mha', 'Vijaysing @ Dnyaneshwar @ Gotya S/O ... vs State Of Mha', 'IARC, 1985, 2004)', 'Vijaysing @ Dnyaneshwar @ Gotya S/O ... vs State Of Mha']
# 100%|██████████| 196/196 [30:47<00:00,  9.43s/it]

# %%
out_df
# Out:
#                                               filename  \
# 0    Abhijeet_Suryakant_Maske_And_Anr_vs_The_State_...
# 1            Amluya_Anand_vs_State_on_8_March_2022.PDF
# 2    Abhijeet_Suryakant_Maske_And_Anr_vs_The_State_...
# 3            Amluya_Anand_vs_State_on_8_March_2022.PDF
# 4    Arulmurugan_Starch_Industries_vs_Food_Safety_A...
# ..                                                 ...
# 196  Vijaysing_Dnyaneshwar_Gotya_S_O_vs_State_Of_Mh...
# 197  Viky_Vikash_Ku_Agrawal_vs_State_Of_Odisha_Opp_...
# 198  Vishnu_Gupta_Lalla_vs_The_State_Of_Madhya_Prad...
# 199  V_Balakrishnan_vs_The_State_Represented_By_on_...
# 200               WP_C__4368_2014_on_25_March_2022.PDF
#
#                          error  \
# 0                           NA
# 1    'provision_statute_pairs'
# 2                           NA
# 3    'provision_statute_pairs'
# 4                           NA
# ..                         ...
# 196  'provision_statute_pairs'
# 197                         NA
# 198                         NA
# 199                         NA
# 200                         NA
#
#                                                  court  \
# 0    [High Court Of Judicature At Bombay, Supreme C...
# 1    [High Court Of Judicature For Rajasthan At\n  ...
# 2    [High Court Of Judicature At Bombay, Supreme C...
# 3    [High Court Of Judicature For Rajasthan At\n  ...
# 4                 [High Court Of Judicature At Madras]
# ..                                                 ...
# 196  [High Court Of Judicature At Bombay, Additiona...
# 197                  [High Court Of Orissa At Cuttack]
# 198      [High Court Of Madhya Pradesh, Supreme Court]
# 199  [High Court Of Judicature At Madras, Judicial ...
# 200  [Gauhati High Court\n  (High Court Of Assam, N...
#
#                                            petitioners  \
# 0    [Abhijeet Suryakant Maske, Abhijeet Suryakant ...
# 1                         [Amluya Anand, Amluya Anand]
# 2    [Abhijeet Suryakant Maske, Abhijeet Suryakant ...
# 3                         [Amluya Anand, Amluya Anand]
# 4    [Arulmurugan Starch Industries, 2018Arulmuruga...
# ..                                                 ...
# 196  [Vijaysing @ Dnyaneshwar @ Gotya, Vijaysingh @...
# 197  [Viky @ Vikash Ku Agrawal, Viky @ Vikash Ku Ag...
# 198       [Vishnu Gupta @ Lalla, Vishnu Gupta @ Lalla]
# 199                   [V.Balakrishnan, V.Balakrishnan]
# 200  [N. Kotiswar Singh, Konto Warisa, Golom Nunisa...
#
#                                            respondents  \
# 0    [State Of Maharashtra, State of Maharashtra, S...
# 1                                       [State, State]
# 2    [State Of Maharashtra, State of Maharashtra, S...
# 3                                       [State, State]
# 4    [Food Safety And Standards, Commissioner of Fo...
# ..                                                 ...
# 196  [State Of Mha, State of\n                     ...
# 197                 [State Of Odisha, State of Odisha]
# 198  [State Of Madhya Pradesh, State Of Madhya Prad...
# 199  [State, 2.Tamil Nadu Food Safety, Public Prose...
# 200  [Sopola Nunisa, Kombo Nunisa, Union of India, ...
#
#                                                 judges  \
# 0    [C.V. Bhadang, C.V. Bhadang, C.V. Bhadang, Sne...
# 1    [Sandeep Mehta, Sandeep Mehta, Merta, CJM Naga...
# 2    [C.V. Bhadang, C.V. Bhadang, C.V. Bhadang, Sne...
# 3    [Sandeep Mehta, Sandeep Mehta, Merta, CJM Naga...
# 4    [Krishnan Ramasamy, Krishnan Ramasamy, KRISHNA...
# ..                                                 ...
# 196  [Avinash G. Gharote, AVINASH G. GHAROTE, Garew...
# 197  [S.K. Sahoo, S.K. Sahoo, S.K. Sahoo, J.M.F.C.,...
# 198                         [Anjuli Palo, ANJULI PALO]
# 199   [M.Nirmal Kumar, M.Nirmal Kumar, M.NIRMAL KUMAR]
# 200  [N. Kotiswar Singh, Malasri\nNandi, N. Kotiswa...
#
#                                                   date  \
# 0    [1 March, 2022, 6 November 2020, 21 September ...
# 1    [08/03/2022, 17/02/2022, 07.04.2015, 24.01.202...
# 2    [1 March, 2022, 6 November 2020, 21 September ...
# 3    [08/03/2022, 17/02/2022, 07.04.2015, 24.01.202...
# 4    [11.7.2018, 19.01.2022, 19 January, 2022, 19.0...
# ..                                                 ...
# 196  [25.11.2021, 24.11.21, 25.11.2021, 13 January,...
# 197  [11.01.2021, 9 February, 2022, 13.04.2021, 9 F...
# 198  [10.8.2021, 22.1.2021, 3 January, 2022, 3 Janu...
# 199  [08.05.2017, 08.05.2017, 17.08.2017, 17.08.201...
# 200  [25.03.2022, 25 March, 2022, 14.07.2009, 19.07...
#
#                                                    org  \
# 0    [Baramati Police Station, Dist, Baramati Polic...
# 1    [Swastik Milk Chilling Centre, Amul Dairy, Amu...
# 2    [Baramati Police Station, Dist, Baramati Polic...
# 3    [Swastik Milk Chilling Centre, Amul Dairy, Amu...
# 4       [Food Safety and Standards Authority of India]
# ..                                                 ...
# 196  [German Cancer Research Centre (DKFZ), Departm...
# 197                                                 []
# 198  [P.S.\nRanjhi, Khadya Suraksha Aur Manak Adhin...
# 199  [Kadavul Mixture Company, Tamil Nadu Food Safe...
# 200  [Haflong Police Station, Dehangi Police Statio...
#
#                                                    gpe  \
# 0                         [Pune, Mumbai, Mumbai, Pune]
# 1    [Nagaur, Thanwla District Nagaur, Jodhpur, Ajm...
# 2                         [Pune, Mumbai, Mumbai, Pune]
# 3    [Nagaur, Thanwla District Nagaur, Jodhpur, Ajm...
# 4        [New Delhi, Chennai, Salem District, Salem-1]
# ..                                                 ...
# 196  [Malkapur-Kurha, Harsoda, State of Maharashtra...
# 197                                                 []
# 198                                         [Jabalpur]
# 199  [Telungupalayam, Coimbatore, Coimbatore, Coimb...
# 200  [Wari Lamphu, Kobak Post, Wari Lampu, Wari Lam...
#
#                                             provisions  \
# 0    [Section 328 of Indian Penal Code, Section 272...
# 1    [Section 468, Section 77, Sections 26(2)(i) an...
# 2    [Section 328 of Indian Penal Code, Section 272...
# 3    [Section 468, Section 77, Sections 26(2)(i) an...
# 4                                                   []
# ..                                                 ...
# 196  [Sections 188, 272, 273, 328, Sections 26(2)(i...
# 197  [section 272/273/420/269/270 of Indian Penal C...
# 198  [Section 420 of Indian Penal Code, Section 272...
# 199  [Section 482 of Criminal Procedure Code, Secti...
# 200  [Section 302 of Indian Penal Code, Section 161...
#
#                                               statutes  \
# 0    [Indian Penal Code, Food Safety and Standards ...
# 1    [Cr, Food Safety and Standards Act, 2006, Food...
# 2    [Indian Penal Code, Food Safety and Standards ...
# 3    [Cr, Food Safety and Standards Act, 2006, Food...
# 4                                                   []
# ..                                                 ...
# 196  [IPC, Food Safety and Standard Act 2006, IPC, ...
# 197  [Indian Penal Code, Cr., Food Safety and Stand...
# 198  [Indian Penal Code, Cr, Food Safety and Standa...
# 199  [Criminal Procedure Code, Food Safety and Stan...
# 200  [Indian Penal Code, Constitution, Criminal Pro...
#
#                                             precedents
# 0    [Abhijeet Suryakant Maske And Anr vs The State...
# 1    [CRLMP-545/2020]Amluya Anand vs State, V.V.S.S...
# 2    [Abhijeet Suryakant Maske And Anr vs The State...
# 3    [CRLMP-545/2020]Amluya Anand vs State, V.V.S.S...
# 4                                                   []
# ..                                                 ...
# 196  [Vijaysing @ Dnyaneshwar @ Gotya S/O ... vs St...
# 197                                                 []
# 198  [Vishnu Gupta @ Lalla vs The State Of Madhya P...
# 199                                                 []
# 200  [Delhi Jal Board v. National Campaign for Dign...
#
# [201 rows x 12 columns]
